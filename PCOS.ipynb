# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pcos_df = pd.read_csv(r"C:\Users\roxy3\OneDrive\UNCC\Spring 2025\Data mining\archive\PCOS_data_without_infertility.csv")

# %%
pcos_df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0     1.0               1.0         0.0        28.0         44.6        152.0
# 1     2.0               2.0         0.0        36.0         65.0        161.5
# 2     3.0               3.0         1.0        33.0         68.8        165.0
# 3     4.0               4.0         0.0        37.0         65.0        148.0
# 4     5.0               5.0         0.0        25.0         52.0        161.0
#
#       BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0    19.3         15.0              78.0              22.0  ...
# 1  #NAME?         15.0              74.0              20.0  ...
# 2  #NAME?         11.0              72.0              18.0  ...
# 3  #NAME?         13.0              72.0              20.0  ...
# 4  #NAME?         11.0              72.0              18.0  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
pcos_df.columns = pcos_df.columns.str.strip()

# %%
pcos_df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)  Age (yrs)  Weight (Kg)  Height(Cm)  \
# 0     1.0               1.0         0.0       28.0         44.6       152.0
# 1     2.0               2.0         0.0       36.0         65.0       161.5
# 2     3.0               3.0         1.0       33.0         68.8       165.0
# 3     4.0               4.0         0.0       37.0         65.0       148.0
# 4     5.0               5.0         0.0       25.0         52.0       161.0
#
#       BMI  Blood Group  Pulse rate(bpm)  RR (breaths/min)  ...  \
# 0    19.3         15.0             78.0              22.0  ...
# 1  #NAME?         15.0             74.0              20.0  ...
# 2  #NAME?         11.0             72.0              18.0  ...
# 3  #NAME?         13.0             72.0              20.0  ...
# 4  #NAME?         11.0             72.0              18.0  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# 0              1.0                0.0                110.0
# ...

# %%
pcos_df['BMI'] = pd.to_numeric(pcos_df['BMI'], errors='coerce')

# %%
pcos_df.loc[:, 'BMI'] = pcos_df['BMI'].fillna(pcos_df['BMI'].mean())

# %%
print(pcos_df['BMI'].isnull().sum())
# Out:
# 0

# %%
print(pcos_df.head())
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)  Age (yrs)  Weight (Kg)  Height(Cm)  \
# 0     1.0               1.0         0.0       28.0         44.6       152.0
# 1     2.0               2.0         0.0       36.0         65.0       161.5
# 2     3.0               3.0         1.0       33.0         68.8       165.0
# 3     4.0               4.0         0.0       37.0         65.0       148.0
# 4     5.0               5.0         0.0       25.0         52.0       161.0
#
#          BMI  Blood Group  Pulse rate(bpm)  RR (breaths/min)  ...  \
# 0  19.300000         15.0             78.0              22.0  ...
# 1  23.929752         15.0             74.0              20.0  ...
# 2  23.929752         11.0             72.0              18.0  ...
# 3  23.929752         13.0             72.0              20.0  ...
# 4  23.929752         11.0             72.0              18.0  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
pcos_df.drop(columns=['Sl. No'], inplace=True, errors='ignore')

# %%
print(pcos_df.columns)
# Out:
# Index(['PCOS (Y/N)', 'Age (yrs)', 'Weight (Kg)', 'Height(Cm)', 'BMI',
#        'Blood Group', 'Pulse rate(bpm)', 'RR (breaths/min)', 'Hb(g/dl)',
#        'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)',
#        'Pregnant(Y/N)', 'No. of aborptions', 'I   beta-HCG(mIU/mL)',
#        'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH',
#        'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)',
#        'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)',
#        'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
print(pcos_df.shape)
# Out:
# (541, 42)

# %%
pcos_df.head()
# Out:
#    Patient File No.  PCOS (Y/N)  Age (yrs)  Weight (Kg)  Height(Cm)  \
# 0               1.0         0.0       28.0         44.6       152.0
# 1               2.0         0.0       36.0         65.0       161.5
# 2               3.0         1.0       33.0         68.8       165.0
# 3               4.0         0.0       37.0         65.0       148.0
# 4               5.0         0.0       25.0         52.0       161.0
#
#          BMI  Blood Group  Pulse rate(bpm)  RR (breaths/min)  Hb(g/dl)  ...  \
# 0  19.300000         15.0             78.0              22.0     10.48  ...
# 1  23.929752         15.0             74.0              20.0     11.70  ...
# 2  23.929752         11.0             72.0              18.0     11.80  ...
# 3  23.929752         13.0             72.0              20.0     12.00  ...
# 4  23.929752         11.0             72.0              18.0     10.00  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
print(pcos_df.describe())
# Out:
#        PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)         BMI  \
# count  541.000000  541.000000   541.000000  541.000000  541.000000
# mean     0.327172   31.430684    59.637153  156.484835   23.929752
# std      0.469615    5.411006    11.028287    6.033545    2.447200
# min      0.000000   20.000000    31.000000  137.000000   15.100000
# 25%      0.000000   28.000000    52.000000  152.000000   23.929752
# 50%      0.000000   31.000000    59.000000  156.000000   23.929752
# 75%      1.000000   35.000000    65.000000  160.000000   23.929752
# max      1.000000   48.000000   108.000000  180.000000   38.900000
#
#        Blood Group  Pulse rate(bpm)  RR (breaths/min)    Hb(g/dl)  Cycle(R/I)  \
# count   541.000000       541.000000        541.000000  541.000000  541.000000
# mean     13.802218        73.247689         19.243993   11.160037    2.560074
# std       1.840812         4.430285          1.688629    0.866904    0.901950
# ...

# %%
print(pcos_df.describe().round(2))
# Out:
#        PCOS (Y/N)  Age (yrs)  Weight (Kg)  Height(Cm)     BMI  Blood Group  \
# count      541.00     541.00       541.00      541.00  541.00       541.00
# mean         0.33      31.43        59.64      156.48   23.93        13.80
# std          0.47       5.41        11.03        6.03    2.45         1.84
# min          0.00      20.00        31.00      137.00   15.10        11.00
# 25%          0.00      28.00        52.00      152.00   23.93        13.00
# 50%          0.00      31.00        59.00      156.00   23.93        14.00
# 75%          1.00      35.00        65.00      160.00   23.93        15.00
# max          1.00      48.00       108.00      180.00   38.90        18.00
#
#        Pulse rate(bpm)  RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  ...  \
# count           541.00            541.00    541.00      541.00  ...
# mean             73.25             19.24     11.16        2.56  ...
# std               4.43              1.69      0.87        0.90  ...
# ...

# %%
pcos_df.drop(columns=['Patient File No.'], inplace=True, errors='ignore')

# %%
pcos_df.head()
# Out:
#    PCOS (Y/N)  Age (yrs)  Weight (Kg)  Height(Cm)        BMI  Blood Group  \
# 0         0.0       28.0         44.6       152.0  19.300000         15.0
# 1         0.0       36.0         65.0       161.5  23.929752         15.0
# 2         1.0       33.0         68.8       165.0  23.929752         11.0
# 3         0.0       37.0         65.0       148.0  23.929752         13.0
# 4         0.0       25.0         52.0       161.0  23.929752         11.0
#
#    Pulse rate(bpm)  RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  ...  Pimples(Y/N)  \
# 0             78.0              22.0     10.48         2.0  ...           0.0
# 1             74.0              20.0     11.70         2.0  ...           0.0
# 2             72.0              18.0     11.80         2.0  ...           1.0
# 3             72.0              20.0     12.00         2.0  ...           0.0
# 4             72.0              18.0     10.00         2.0  ...           0.0
#
# ...

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(pcos_df.corr(), cmap="coolwarm", annot=False, linewidths=0.5)
plt.title("Correlation Heatmap of Clinical Features")
plt.show()

# %%
plt.figure(figsize=(14, 10))  
sns.heatmap(pcos_df.corr(), cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5)
plt.xticks(rotation=90)  
plt.yticks(rotation=0) 
plt.title("Correlation Heatmap of Clinical Features", fontsize=16)
plt.show()

# %%
sns.heatmap(pcos_df.corr(), cmap="RdBu_r", annot=True, fmt=".2f", linewidths=0.5)
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(16, 12))  
sns.heatmap(pcos_df.corr(), cmap="RdBu_r", annot=True, fmt=".1f", linewidths=0.5, annot_kws={"size": 8})
plt.xticks(rotation=90, fontsize=10)  
plt.yticks(fontsize=10)
plt.title("Correlation Heatmap of Clinical Features", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(14, 10)) 
sns.heatmap(
    pcos_df.corr(), 
    cmap="coolwarm", 
    annot=True, 
    fmt=".2f", 
    linewidths=0.5, 
    annot_kws={"size": 8}  
)
plt.xticks(rotation=90, fontsize=10)  
plt.yticks(fontsize=10)
plt.title("Correlation Heatmap of Clinical Features", fontsize=16)
plt.show()

# %%
corr_matrix = pcos_df.corr()
strong_corr = corr_matrix[(corr_matrix >= 0.5) | (corr_matrix <= -0.5)]
sns.heatmap(strong_corr, cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5)
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(12, 10))  
sns.heatmap(
    strong_corr, 
    cmap="coolwarm", 
    annot=True, 
    fmt=".2f", 
    linewidths=0.5, 
    annot_kws={"size": 10}  
)
plt.xticks(rotation=45, ha="right", fontsize=10)  
plt.yticks(fontsize=10)
plt.title("Strong Correlations in Clinical Features", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x="PCOS (Y/N)", y="BMI", data=pcos_df, inner="quartile")
plt.title("BMI Distribution Among PCOS and Non-PCOS Individuals")
plt.xlabel("PCOS Diagnosis")
plt.ylabel("BMI")
plt.xticks(ticks=[0, 1], labels=["Non-PCOS", "PCOS"])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=pcos_df, x="Age (yrs)", y="BMI", hue="PCOS (Y/N)", alpha=0.7)
plt.title("BMI vs. Age with PCOS Diagnosis")
plt.xlabel("Age (years)")
plt.ylabel("BMI")
plt.legend(["Non-PCOS", "PCOS"])
plt.show()

# %%
plt.figure(figsize=(12, 6))

#LH levels
plt.subplot(1, 3, 1)
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=pcos_df)
plt.title("LH Levels in PCOS vs. Non-PCOS")
plt.xlabel("PCOS Diagnosis")
plt.ylabel("LH (mIU/mL)")
plt.xticks([0, 1], ["Non-PCOS", "PCOS"])

# FSH levels
plt.subplot(1, 3, 2)
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=pcos_df)
plt.title("FSH Levels in PCOS vs. Non-PCOS")
plt.xlabel("PCOS Diagnosis")
plt.ylabel("FSH (mIU/mL)")
plt.xticks([0, 1], ["Non-PCOS", "PCOS"])

# Testosterone levels
plt.subplot(1, 3, 3)
sns.boxplot(x="PCOS (Y/N)", y="Testosterone(ng/dL)", data=pcos_df)
plt.title("Testosterone Levels in PCOS vs. Non-PCOS")
plt.xlabel("PCOS Diagnosis")
plt.ylabel("Testosterone (ng/dL)")
plt.xticks([0, 1], ["Non-PCOS", "PCOS"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 21
#      19 # Testosterone levels
#      20 plt.subplot(1, 3, 3)
# ---> 21 sns.boxplot(x="PCOS (Y/N)", y="Testosterone(ng/dL)", data=pcos_df)
#      22 plt.title("Testosterone Levels in PCOS vs. Non-PCOS")
#      23 plt.xlabel("PCOS Diagnosis")
#
# File ~\anaconda3\envs\ITCS3162\Lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
print(pcos_df.columns)
# Out:
# Index(['PCOS (Y/N)', 'Age (yrs)', 'Weight (Kg)', 'Height(Cm)', 'BMI',
#        'Blood Group', 'Pulse rate(bpm)', 'RR (breaths/min)', 'Hb(g/dl)',
#        'Cycle(R/I)', 'Cycle length(days)', 'Marraige Status (Yrs)',
#        'Pregnant(Y/N)', 'No. of aborptions', 'I   beta-HCG(mIU/mL)',
#        'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH',
#        'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)',
#        'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)',
#        'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')

# %%
for col in pcos_df.columns:
    print(f"'{col}'")
# Out:
# 'PCOS (Y/N)'
# 'Age (yrs)'
# 'Weight (Kg)'
# 'Height(Cm)'
# 'BMI'
# 'Blood Group'
# 'Pulse rate(bpm)'
# 'RR (breaths/min)'
# 'Hb(g/dl)'
# 'Cycle(R/I)'
# 'Cycle length(days)'
# 'Marraige Status (Yrs)'
# 'Pregnant(Y/N)'
# 'No. of aborptions'
# 'I   beta-HCG(mIU/mL)'
# 'II    beta-HCG(mIU/mL)'
# 'FSH(mIU/mL)'
# 'LH(mIU/mL)'
# 'FSH/LH'
# 'Hip(inch)'
# 'Waist(inch)'
# 'Waist:Hip Ratio'
# 'TSH (mIU/L)'
# 'AMH(ng/mL)'
# 'PRL(ng/mL)'
# 'Vit D3 (ng/mL)'
# 'PRG(ng/mL)'
# 'RBS(mg/dl)'
# 'Weight gain(Y/N)'
# 'hair growth(Y/N)'
# 'Skin darkening (Y/N)'
# 'Hair loss(Y/N)'
# 'Pimples(Y/N)'
# 'Fast food (Y/N)'
# 'Reg.Exercise(Y/N)'
# 'BP _Systolic (mmHg)'
# 'BP _Diastolic (mmHg)'
# 'Follicle No. (L)'
# 'Follicle No. (R)'
# 'Avg. F size (L) (mm)'
# 'Avg. F size (R) (mm)'
# 'Endometrium (mm)'

# %%
plt.figure(figsize=(12, 6))

# LH Levels
plt.subplot(1, 4, 1)
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=pcos_df)
plt.title("LH Levels in PCOS vs. Non-PCOS")

# FSH Levels
plt.subplot(1, 4, 2)
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=pcos_df)
plt.title("FSH Levels in PCOS vs. Non-PCOS")

# PRL Levels
plt.subplot(1, 4, 3)
sns.boxplot(x="PCOS (Y/N)", y="PRL(ng/mL)", data=pcos_df)
plt.title("Prolactin Levels in PCOS vs. Non-PCOS")

# AMH Levels
plt.subplot(1, 4, 4)
sns.boxplot(x="PCOS (Y/N)", y="AMH(ng/mL)", data=pcos_df)
plt.title("AMH Levels in PCOS vs. Non-PCOS")
# Out:
# Text(0.5, 1.0, 'AMH Levels in PCOS vs. Non-PCOS')

# %%
plt.figure(figsize=(12, 6))

# LH Levels
plt.subplot(1, 4, 1)
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=pcos_df)
plt.title("LH Levels in PCOS vs. Non-PCOS")

# FSH Levels
plt.subplot(1, 4, 2)
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=pcos_df)
plt.title("FSH Levels in PCOS vs. Non-PCOS")
# Out:
# Text(0.5, 1.0, 'FSH Levels in PCOS vs. Non-PCOS')

# %%
plt.subplot(1, 2, 1)
sns.boxplot(x="PCOS (Y/N)", y="LH(mIU/mL)", data=pcos_df, palette="coolwarm")
plt.title("LH Levels in PCOS vs. Non-PCOS", fontsize=12)
plt.xlabel("PCOS Diagnosis", fontsize=10)
plt.ylabel("LH (mIU/mL)", fontsize=10)
plt.ylim(0, 20)
# Out:
# (0.0, 20.0)

# %%
plt.subplot(1, 2, 2)
sns.boxplot(x="PCOS (Y/N)", y="FSH(mIU/mL)", data=pcos_df, palette="coolwarm")
plt.title("FSH Levels in PCOS vs. Non-PCOS", fontsize=12)
plt.xlabel("PCOS Diagnosis", fontsize=10)
plt.ylabel("FSH (mIU/mL)", fontsize=10)
plt.ylim(0, 20)
# Out:
# (0.0, 20.0)

# %%
plt.subplot(1, 4, 3)
sns.boxplot(x="PCOS (Y/N)", y="PRL(ng/mL)", data=pcos_df)
plt.title("Prolactin Levels in PCOS vs. Non-PCOS")
# Out:
# Text(0.5, 1.0, 'Prolactin Levels in PCOS vs. Non-PCOS')

# %%
plt.subplot(1, 4, 4)
sns.boxplot(x="PCOS (Y/N)", y="AMH(ng/mL)", data=pcos_df)
plt.title("AMH Levels in PCOS vs. Non-PCOS")
# Out:
# Text(0.5, 1.0, 'AMH Levels in PCOS vs. Non-PCOS')
